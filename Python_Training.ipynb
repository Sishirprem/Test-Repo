# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = {'price': [100, 200, 150, 300, 250],'time': [1, 2, 3, 4, 5]}

# %%
df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#             price      time
# count    5.000000  5.000000
# mean   200.000000  3.000000
# std     79.056942  1.581139
# min    100.000000  1.000000
# 25%    150.000000  2.000000
# 50%    200.000000  3.000000
# 75%    250.000000  4.000000
# max    300.000000  5.000000

# %%
df.head()
# Out:
#    price  time
# 0    100     1
# 1    200     2
# 2    150     3
# 3    300     4
# 4    250     5

# %%
correlation_matrix = df.corr()

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['price'],df['time'],marker='*',linestyle='-',color='r')
plt.xlabel('price')
plt.ylabel('time')
plt.grid(True)
plt.xticks(rotation=45)
plt.title('Correlation Matrix between Price and Time')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidth='.5')
plt.xlabel('price')
plt.ylabel('time')
plt.grid(True)
plt.xticks(rotation=45)
plt.title('Correlation Matrix between Price and Time')
plt.show()
